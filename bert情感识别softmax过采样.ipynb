# %%
import time
import torch
import numpy as np
from train_eval import train, init_network
from importlib import import_module
import argparse
# from utils import build_dataset, build_iterator, get_time_dif


dataset = 'Newtrain_qinggan'  # 数据集

model_name = 'bert'  # bert
x = import_module('models.' + model_name)
config = x.Config(dataset)

# %%
import torch
from tqdm import tqdm
import time
import random
from datetime import timedelta

PAD, CLS = '[PAD]', '[CLS]'  # padding符号, bert中综合信息符号
class_list = ['价格', '配置', '操控', '舒适性', '油耗', '动力', '内饰', '安全性', '空间', '外观']

def build_dataset_bert(config):

    def load_dataset(path, pad_size=32):
        contents = []
        with open(path, 'r', encoding='UTF-8') as f:
            for line in tqdm(f):
                lin = line.strip()
                if not lin:
                    continue
                tmp_data = lin.split('\t')
                content = tmp_data[0].replace(" ", "")
                # content, label = lin.split('\t')
                token = config.tokenizer.tokenize(content)
                zhuti_label = [class_list.index(t.split('#')[0]) for t in tmp_data[1:]]

                cal_qinggan = sum([int(t.split('#')[1]) for t in tmp_data[1:]])
                qinggan_label = 1
                if cal_qinggan > 0:
                    qinggan_label = 2
                elif cal_qinggan < 0:
                    qinggan_label = 0

                token = [CLS] + token
                seq_len = len(token)
                mask = []
                token_ids = config.tokenizer.convert_tokens_to_ids(token)

                if pad_size:
                    if len(token) < pad_size:
                        mask = [1] * len(token_ids) + [0] * (pad_size - len(token))
                        token_ids += ([0] * (pad_size - len(token)))
                    else:
                        mask = [1] * pad_size
                        token_ids = token_ids[:pad_size]
                        seq_len = pad_size
                contents.append((token_ids, zhuti_label, int(qinggan_label), seq_len, mask))
                if 'test' not in path:
                    # 过采样
                    if qinggan_label in [0, 2]:
                        for copyy in range(4):
                             contents.append((token_ids, zhuti_label, int(qinggan_label), seq_len, mask))
                    # 欠采样
                    # if qinggan_label not in [0, 2]:
                    #     if random.random() > 0.2:
                    #         contents.pop()
        return contents
    train = load_dataset(config.train_path, config.pad_size)
    test = load_dataset(config.test_path, config.pad_size)
    random.shuffle(train)
    random.shuffle(test)
    return train, test


train, test = build_dataset_bert(config)
print(len(train), len(test))
from collections import defaultdict
c = defaultdict(int)
for i in train:
    c[i[2]] += 1
print(c)
# Out:
# 8000it [00:01, 5169.22it/s]
# 2653it [00:00, 4789.50it/s]
# 17360 2653
# defaultdict(<class 'int'>, {0: 5980, 1: 5660, 2: 5720})

# %%
import torch
import torch.nn.functional as F
from utils import build_iterator_bert
train_iter = build_iterator_bert(train, config)
test_iter = build_iterator_bert(test, config)

# print(train_iter.__next__()[0])
model = x.Model(config).to(config.device)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn import metrics
import time
from utils import get_time_dif
from pytorch_pretrained.optimization import BertAdam
import numpy as np
import torch
import json
import torch.nn as nn
import torch.nn.functional as F
from sklearn import metrics
import time
from collections import defaultdict
from utils import get_time_dif
from tensorboardX import SummaryWriter

config.num_epochs = 50
config.require_improvement = 500
config.log_path = dataset + '/log/' + config.model_name
class FocalLoss(nn.Module):
    """
    参考 https://github.com/lonePatient/TorchBlocks
    """

    def __init__(self, gamma=2.0, alpha=1, epsilon=1.e-9, device=None):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        if isinstance(alpha, list):
            self.alpha = torch.Tensor(alpha).to(config.device)
        else:
            self.alpha = alpha
        self.epsilon = epsilon

    def forward(self, input, target):
        """
        Args:
            input: model's output, shape of [batch_size, num_cls]
            target: ground truth labels, shape of [batch_size]
        Returns:
            shape of [batch_size]
        """
        num_labels = input.size(-1)
        idx = target.view(-1, 1).long()
        one_hot_key = torch.zeros(idx.size(0), num_labels, dtype=torch.float32, device=idx.device)
        one_hot_key = one_hot_key.scatter_(1, idx, 1)
        one_hot_key[:, 0] = 0  # ignore 0 index.
        logits = torch.softmax(input, dim=-1)
        # print(one_hot_key)
        # print(sdf)
        loss = -self.alpha * one_hot_key * torch.pow((1 - logits), self.gamma) * (logits + self.epsilon).log()
        loss = loss.sum(1)
        return loss.mean()

def train_qinggan(config, model, train_iter, test_iter):
    start_time = time.time()
    model.train()
    param_optimizer = list(model.named_parameters())
    no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
    optimizer_grouped_parameters = [
        {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
        {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}]
    # optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
    optimizer = BertAdam(optimizer_grouped_parameters,
                         lr=config.learning_rate,
                         warmup=0.05,
                         t_total=len(train_iter) * config.num_epochs)
    total_batch = 0  # 记录进行到多少batch
    dev_best_loss = float('inf')
    train_dict = defaultdict(list)
    test_dict = defaultdict(list)
    loss_fn = FocalLoss(alpha=[1, 1, 1], device = config.device)
    last_improve = 0  # 记录上次验证集loss下降的batch数
    flag = False  # 记录是否很久没有效果提升
    model.train()
    for epoch in range(config.num_epochs):
        print('Epoch [{}/{}]'.format(epoch + 1, config.num_epochs))
        for i, (trains, qinggan_label, zhuti_label) in enumerate(train_iter):
            outputs = model(trains)
            model.zero_grad()
            # loss = F.cross_entropy(outputs, labels)
            qinggan_label = qinggan_label.to(config.device)
            # loss = FocalLoss(alpha=[8000 / 1196, 8000/5660, 8000/1144])
            # loss = loss_fn(outputs, qinggan_label)
            loss = F.cross_entropy(outputs, qinggan_label)
            loss.backward()
            optimizer.step()
            if total_batch % 10 == 0:
                # 每多少轮输出在训练集和验证集上的效果
                true = qinggan_label.data.cpu()
                predic = torch.max(outputs.data, 1)[1].cpu()
                train_acc = metrics.accuracy_score(true, predic)
                train_precision = metrics.precision_score(true, predic, average='macro', zero_division=0)
                train_recall = metrics.recall_score(true, predic, average='macro', zero_division=0)
                train_f1 = 2 * (train_precision * train_recall) / (train_precision + train_recall + 1e-5)
                # dev_acc, dev_loss = evaluate_qinggan(config, model, dev_iter)
                dev_acc, dev_loss, dev_p, dev_r, dev_f1 = evaluate_qinggan(config, model, test_iter)
                if dev_loss < dev_best_loss:
                    dev_best_loss = dev_loss
                    torch.save(model.state_dict(), config.save_path)
                    improve = '*improve'
                    last_improve = total_batch
                else:
                    improve = ''
                time_dif = get_time_dif(start_time)
                msg = 'Iter: {0:>6},  Train Loss: {1:>5.2},  Train Acc: {2:>6.2%},  Val Loss: {3:>5.2},  Val Acc: {4:>6.2%},  Time: {5} {6}'
                print(msg.format(total_batch, loss.item(), train_acc, dev_loss, dev_acc, time_dif, improve))
                train_dict['train_loss'].append(loss.item())   
                train_dict['train_acc'].append(train_acc)
                train_dict['train_precision'].append(train_precision)
                train_dict['train_recall'].append(train_recall)
                train_dict['train_f1'].append(train_f1)
                test_dict['dev_acc'].append(dev_acc)
                test_dict['dev_loss'].append(dev_loss.item())
                test_dict['dev_precision'].append(dev_p)
                test_dict['dev_recall'].append(dev_r)
                test_dict['dev_f1'].append(dev_f1)
                with open(config.log_path + '/train_dict.json', 'w') as json_file:
                    json.dump(train_dict, json_file, indent=4)  # indent参数使输出更加易读
                with open(config.log_path + '/test_dict.json', 'w') as json_file:
                    json.dump(test_dict, json_file, indent=4)  # indent参数使输出更加易读
                model.train()
            total_batch += 1
            if total_batch - last_improve > config.require_improvement:
                # 验证集loss超过1000batch没下降，结束训练
                print("No optimization for a long time, auto-stopping...")
                flag = True
                break
        if flag:
            break


def evaluate_qinggan(config, model, data_iter, test=False):
    model.eval()
    loss_total = 0
    predict_all = np.array([], dtype=int)
    labels_all = np.array([], dtype=int)
    loss_fn = FocalLoss(alpha=[1, 1, 1],  device = config.device)
    with torch.no_grad():
        for texts, qinggan_label, zhuti_label in data_iter:
            outputs = model(texts)

            qinggan_label = qinggan_label.to(config.device)
            loss = F.cross_entropy(outputs, qinggan_label)
            # loss = loss_fn(outputs, qinggan_label)
            loss_total += loss
            labels = qinggan_label.data.cpu().numpy()
            predic = torch.max(outputs.data, 1)[1].cpu().numpy()
            labels_all = np.append(labels_all, labels)
            predict_all = np.append(predict_all, predic)

    acc = metrics.accuracy_score(labels_all, predict_all)
    p = metrics.precision_score(labels_all, predict_all, average='macro', zero_division=0)
    r = metrics.recall_score(labels_all, predict_all, average='macro', zero_division=0)
    f1 =  2 * (p * r) / (p + r + 1e-5)

    return acc, loss_total / len(data_iter), p, r, f1

train_qinggan(config, model, train_iter, test_iter)
# Out:
# Epoch [1/50]
# /mnt/workspace/Bertchinese/pytorch_pretrained/optimization.py:275: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1055.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# Iter:      0,  Train Loss:   1.3,  Train Acc: 37.50%,  Val Loss:   1.3,  Val Acc: 14.36%,  Time: 0:00:02 *improve
# Iter:     10,  Train Loss:   1.3,  Train Acc: 28.91%,  Val Loss:   1.4,  Val Acc: 20.24%,  Time: 0:00:05
# Iter:     20,  Train Loss:   1.1,  Train Acc: 43.75%,  Val Loss:   1.1,  Val Acc: 33.62%,  Time: 0:00:09 *improve
# Iter:     30,  Train Loss:   1.0,  Train Acc: 49.22%,  Val Loss:   1.0,  Val Acc: 48.74%,  Time: 0:00:13 *improve
# Iter:     40,  Train Loss:  0.94,  Train Acc: 53.12%,  Val Loss:  0.94,  Val Acc: 58.05%,  Time: 0:00:16 *improve
# Iter:     50,  Train Loss:  0.83,  Train Acc: 64.06%,  Val Loss:  0.91,  Val Acc: 57.37%,  Time: 0:00:20 *improve
# Iter:     60,  Train Loss:  0.89,  Train Acc: 59.38%,  Val Loss:   0.9,  Val Acc: 58.88%,  Time: 0:00:24 *improve
# Iter:     70,  Train Loss:  0.78,  Train Acc: 64.84%,  Val Loss:   0.9,  Val Acc: 56.28%,  Time: 0:00:27
# Iter:     80,  Train Loss:  0.77,  Train Acc: 67.97%,  Val Loss:  0.93,  Val Acc: 57.67%,  Time: 0:00:30
# Iter:     90,  Train Loss:  0.73,  Train Acc: 72.66%,  Val Loss:   1.1,  Val Acc: 49.34%,  Time: 0:00:33
# Iter:    100,  Train Loss:  0.75,  Train Acc: 68.75%,  Val Loss:   1.1,  Val Acc: 45.76%,  Time: 0:00:37
# Iter:    110,  Train Loss:  0.71,  Train Acc: 69.53%,  Val Loss:   1.0,  Val Acc: 53.52%,  Time: 0:00:40
# Iter:    120,  Train Loss:  0.71,  Train Acc: 67.97%,  Val Loss:  0.91,  Val Acc: 59.67%,  Time: 0:00:43
# Iter:    130,  Train Loss:  0.66,  Train Acc: 71.88%,  Val Loss:  0.81,  Val Acc: 63.66%,  Time: 0:00:47 *improve
# Epoch [2/50]
# Iter:    140,  Train Loss:  0.61,  Train Acc: 71.88%,  Val Loss:  0.88,  Val Acc: 62.16%,  Time: 0:00:50
# Iter:    150,  Train Loss:  0.71,  Train Acc: 71.88%,  Val Loss:  0.92,  Val Acc: 61.89%,  Time: 0:00:53
# Iter:    160,  Train Loss:  0.64,  Train Acc: 74.22%,  Val Loss:  0.94,  Val Acc: 57.03%,  Time: 0:00:56
# Iter:    170,  Train Loss:  0.51,  Train Acc: 79.69%,  Val Loss:   1.1,  Val Acc: 56.43%,  Time: 0:00:59
# Iter:    180,  Train Loss:  0.53,  Train Acc: 78.12%,  Val Loss:  0.99,  Val Acc: 57.71%,  Time: 0:01:02
# Iter:    190,  Train Loss:  0.38,  Train Acc: 88.28%,  Val Loss:   1.0,  Val Acc: 61.74%,  Time: 0:01:06
# Iter:    200,  Train Loss:  0.35,  Train Acc: 86.72%,  Val Loss:   1.1,  Val Acc: 55.37%,  Time: 0:01:09
# Iter:    210,  Train Loss:  0.37,  Train Acc: 86.72%,  Val Loss:   1.0,  Val Acc: 62.53%,  Time: 0:01:12
# Iter:    220,  Train Loss:  0.38,  Train Acc: 84.38%,  Val Loss:   1.0,  Val Acc: 61.55%,  Time: 0:01:15
# Iter:    230,  Train Loss:  0.56,  Train Acc: 82.03%,  Val Loss:   1.1,  Val Acc: 64.15%,  Time: 0:01:18
# Iter:    240,  Train Loss:  0.42,  Train Acc: 85.16%,  Val Loss:  0.97,  Val Acc: 64.04%,  Time: 0:01:22
# Iter:    250,  Train Loss:  0.29,  Train Acc: 89.06%,  Val Loss:   1.0,  Val Acc: 63.25%,  Time: 0:01:25
# Iter:    260,  Train Loss:  0.34,  Train Acc: 89.06%,  Val Loss:   1.2,  Val Acc: 57.63%,  Time: 0:01:28
# Iter:    270,  Train Loss:  0.24,  Train Acc: 90.62%,  Val Loss:   1.1,  Val Acc: 67.06%,  Time: 0:01:31
# Epoch [3/50]
# Iter:    280,  Train Loss:   0.3,  Train Acc: 91.41%,  Val Loss:   1.1,  Val Acc: 65.81%,  Time: 0:01:34
# Iter:    290,  Train Loss:  0.31,  Train Acc: 86.72%,  Val Loss:   1.1,  Val Acc: 66.60%,  Time: 0:01:37
# Iter:    300,  Train Loss:  0.21,  Train Acc: 93.75%,  Val Loss:   1.3,  Val Acc: 61.93%,  Time: 0:01:41
# Iter:    310,  Train Loss:  0.23,  Train Acc: 93.75%,  Val Loss:   1.0,  Val Acc: 66.91%,  Time: 0:01:44
# Iter:    320,  Train Loss:  0.24,  Train Acc: 92.97%,  Val Loss:   1.2,  Val Acc: 66.23%,  Time: 0:01:47
# Iter:    330,  Train Loss:  0.11,  Train Acc: 96.88%,  Val Loss:   1.4,  Val Acc: 63.66%,  Time: 0:01:50
# Iter:    340,  Train Loss:   0.3,  Train Acc: 91.41%,  Val Loss:   1.3,  Val Acc: 66.49%,  Time: 0:01:53
# Iter:    350,  Train Loss:   0.2,  Train Acc: 89.84%,  Val Loss:   1.4,  Val Acc: 60.99%,  Time: 0:01:56
# Iter:    360,  Train Loss:  0.16,  Train Acc: 95.31%,  Val Loss:   1.2,  Val Acc: 64.19%,  Time: 0:02:00
# Iter:    370,  Train Loss:  0.31,  Train Acc: 91.41%,  Val Loss:   1.3,  Val Acc: 63.06%,  Time: 0:02:03
# Iter:    380,  Train Loss:  0.25,  Train Acc: 91.41%,  Val Loss:   1.2,  Val Acc: 62.68%,  Time: 0:02:06
# Iter:    390,  Train Loss:  0.13,  Train Acc: 96.09%,  Val Loss:   1.2,  Val Acc: 61.48%,  Time: 0:02:09
# Iter:    400,  Train Loss:  0.19,  Train Acc: 92.97%,  Val Loss:   1.3,  Val Acc: 65.85%,  Time: 0:02:12
# Epoch [4/50]
# Iter:    410,  Train Loss:  0.25,  Train Acc: 92.19%,  Val Loss:   1.4,  Val Acc: 66.08%,  Time: 0:02:16
# Iter:    420,  Train Loss:  0.18,  Train Acc: 90.62%,  Val Loss:   1.3,  Val Acc: 67.02%,  Time: 0:02:19
# Iter:    430,  Train Loss:   0.2,  Train Acc: 93.75%,  Val Loss:   1.3,  Val Acc: 67.58%,  Time: 0:02:22
# Iter:    440,  Train Loss: 0.077,  Train Acc: 98.44%,  Val Loss:   1.4,  Val Acc: 66.42%,  Time: 0:02:25
# Iter:    450,  Train Loss:  0.19,  Train Acc: 93.75%,  Val Loss:   1.4,  Val Acc: 69.47%,  Time: 0:02:28
# Iter:    460,  Train Loss:  0.12,  Train Acc: 95.31%,  Val Loss:   1.4,  Val Acc: 68.68%,  Time: 0:02:31
# Iter:    470,  Train Loss: 0.067,  Train Acc: 96.09%,  Val Loss:   1.4,  Val Acc: 66.75%,  Time: 0:02:35
# Iter:    480,  Train Loss:  0.14,  Train Acc: 95.31%,  Val Loss:   1.4,  Val Acc: 66.26%,  Time: 0:02:38
# Iter:    490,  Train Loss: 0.041,  Train Acc: 99.22%,  Val Loss:   1.5,  Val Acc: 63.17%,  Time: 0:02:41
# Iter:    500,  Train Loss: 0.063,  Train Acc: 98.44%,  Val Loss:   1.4,  Val Acc: 63.44%,  Time: 0:02:44
# Iter:    510,  Train Loss:  0.04,  Train Acc: 98.44%,  Val Loss:   1.5,  Val Acc: 67.06%,  Time: 0:02:47
# Iter:    520,  Train Loss:  0.22,  Train Acc: 91.41%,  Val Loss:   1.7,  Val Acc: 60.31%,  Time: 0:02:50
# Iter:    530,  Train Loss: 0.052,  Train Acc: 98.44%,  Val Loss:   1.5,  Val Acc: 65.62%,  Time: 0:02:54
# Iter:    540,  Train Loss: 0.053,  Train Acc: 98.44%,  Val Loss:   1.4,  Val Acc: 67.40%,  Time: 0:02:57
# Epoch [5/50]
# Iter:    550,  Train Loss: 0.045,  Train Acc: 97.66%,  Val Loss:   1.5,  Val Acc: 68.56%,  Time: 0:03:00
# Iter:    560,  Train Loss: 0.066,  Train Acc: 97.66%,  Val Loss:   1.7,  Val Acc: 68.34%,  Time: 0:03:03
# Iter:    570,  Train Loss: 0.028,  Train Acc: 99.22%,  Val Loss:   1.7,  Val Acc: 65.47%,  Time: 0:03:06
# Iter:    580,  Train Loss:  0.04,  Train Acc: 97.66%,  Val Loss:   1.6,  Val Acc: 64.79%,  Time: 0:03:09
# Iter:    590,  Train Loss: 0.099,  Train Acc: 96.88%,  Val Loss:   1.6,  Val Acc: 65.10%,  Time: 0:03:13
# Iter:    600,  Train Loss: 0.035,  Train Acc: 98.44%,  Val Loss:   1.6,  Val Acc: 65.51%,  Time: 0:03:16
# Iter:    610,  Train Loss: 0.034,  Train Acc: 99.22%,  Val Loss:   1.6,  Val Acc: 67.89%,  Time: 0:03:19
# Iter:    620,  Train Loss: 0.013,  Train Acc: 100.00%,  Val Loss:   1.6,  Val Acc: 65.96%,  Time: 0:03:22
# Iter:    630,  Train Loss: 0.036,  Train Acc: 100.00%,  Val Loss:   1.6,  Val Acc: 65.66%,  Time: 0:03:25
# Iter:    640,  Train Loss: 0.068,  Train Acc: 97.66%,  Val Loss:   1.5,  Val Acc: 65.89%,  Time: 0:03:29
# Iter:    650,  Train Loss: 0.023,  Train Acc: 99.22%,  Val Loss:   1.6,  Val Acc: 66.87%,  Time: 0:03:32
# Iter:    660,  Train Loss: 0.033,  Train Acc: 99.22%,  Val Loss:   1.7,  Val Acc: 68.56%,  Time: 0:03:35
# Iter:    670,  Train Loss:  0.02,  Train Acc: 99.22%,  Val Loss:   1.7,  Val Acc: 64.98%,  Time: 0:03:38
# Epoch [6/50]
# Iter:    680,  Train Loss: 0.038,  Train Acc: 98.44%,  Val Loss:   1.7,  Val Acc: 64.53%,  Time: 0:03:41
# Iter:    690,  Train Loss: 0.053,  Train Acc: 98.44%,  Val Loss:   1.7,  Val Acc: 68.49%,  Time: 0:03:44
# Iter:    700,  Train Loss: 0.081,  Train Acc: 96.09%,  Val Loss:   1.8,  Val Acc: 68.22%,  Time: 0:03:48
# Iter:    710,  Train Loss: 0.091,  Train Acc: 97.66%,  Val Loss:   1.7,  Val Acc: 65.21%,  Time: 0:03:51
# Iter:    720,  Train Loss: 0.017,  Train Acc: 99.22%,  Val Loss:   1.6,  Val Acc: 63.66%,  Time: 0:03:54
# Iter:    730,  Train Loss: 0.023,  Train Acc: 99.22%,  Val Loss:   1.6,  Val Acc: 67.47%,  Time: 0:03:57
# Iter:    740,  Train Loss: 0.027,  Train Acc: 98.44%,  Val Loss:   1.7,  Val Acc: 68.04%,  Time: 0:04:00
# Iter:    750,  Train Loss: 0.055,  Train Acc: 99.22%,  Val Loss:   1.8,  Val Acc: 67.96%,  Time: 0:04:03
# Iter:    760,  Train Loss: 0.061,  Train Acc: 98.44%,  Val Loss:   1.8,  Val Acc: 68.22%,  Time: 0:04:07
# Iter:    770,  Train Loss: 0.0089,  Train Acc: 100.00%,  Val Loss:   1.8,  Val Acc: 67.85%,  Time: 0:04:10
# Iter:    780,  Train Loss: 0.022,  Train Acc: 99.22%,  Val Loss:   1.8,  Val Acc: 67.32%,  Time: 0:04:13
# Iter:    790,  Train Loss: 0.0028,  Train Acc: 100.00%,  Val Loss:   1.8,  Val Acc: 66.53%,  Time: 0:04:16
# Iter:    800,  Train Loss: 0.054,  Train Acc: 98.44%,  Val Loss:   1.9,  Val Acc: 68.64%,  Time: 0:04:19
# Iter:    810,  Train Loss: 0.0091,  Train Acc: 100.00%,  Val Loss:   1.9,  Val Acc: 68.41%,  Time: 0:04:23
# Epoch [7/50]
# Iter:    820,  Train Loss: 0.035,  Train Acc: 98.44%,  Val Loss:   1.9,  Val Acc: 65.32%,  Time: 0:04:26
# Iter:    830,  Train Loss: 0.045,  Train Acc: 99.22%,  Val Loss:   1.8,  Val Acc: 68.83%,  Time: 0:04:29
# Iter:    840,  Train Loss: 0.038,  Train Acc: 98.44%,  Val Loss:   1.7,  Val Acc: 68.26%,  Time: 0:04:32
# Iter:    850,  Train Loss: 0.032,  Train Acc: 98.44%,  Val Loss:   1.7,  Val Acc: 67.85%,  Time: 0:04:35
# Iter:    860,  Train Loss: 0.016,  Train Acc: 99.22%,  Val Loss:   1.7,  Val Acc: 68.22%,  Time: 0:04:38
# Iter:    870,  Train Loss: 0.041,  Train Acc: 98.44%,  Val Loss:   1.8,  Val Acc: 67.51%,  Time: 0:04:42
# Iter:    880,  Train Loss: 0.0051,  Train Acc: 100.00%,  Val Loss:   1.9,  Val Acc: 66.19%,  Time: 0:04:45
# Iter:    890,  Train Loss: 0.073,  Train Acc: 98.44%,  Val Loss:   1.8,  Val Acc: 68.00%,  Time: 0:04:48
# Iter:    900,  Train Loss: 0.014,  Train Acc: 99.22%,  Val Loss:   1.8,  Val Acc: 68.11%,  Time: 0:04:51
# Iter:    910,  Train Loss: 0.056,  Train Acc: 98.44%,  Val Loss:   1.8,  Val Acc: 66.83%,  Time: 0:04:54
# Iter:    920,  Train Loss: 0.014,  Train Acc: 99.22%,  Val Loss:   1.7,  Val Acc: 68.19%,  Time: 0:04:58
# Iter:    930,  Train Loss:  0.04,  Train Acc: 98.44%,  Val Loss:   1.8,  Val Acc: 67.70%,  Time: 0:05:01
# Iter:    940,  Train Loss: 0.037,  Train Acc: 99.22%,  Val Loss:   1.8,  Val Acc: 68.56%,  Time: 0:05:04
# Iter:    950,  Train Loss:  0.03,  Train Acc: 98.44%,  Val Loss:   1.8,  Val Acc: 67.92%,  Time: 0:05:07
# Epoch [8/50]
# Iter:    960,  Train Loss: 0.016,  Train Acc: 99.22%,  Val Loss:   1.9,  Val Acc: 67.43%,  Time: 0:05:10
# Iter:    970,  Train Loss: 0.012,  Train Acc: 99.22%,  Val Loss:   1.8,  Val Acc: 67.66%,  Time: 0:05:13
# Iter:    980,  Train Loss: 0.023,  Train Acc: 99.22%,  Val Loss:   1.8,  Val Acc: 66.68%,  Time: 0:05:17
# Iter:    990,  Train Loss: 0.011,  Train Acc: 99.22%,  Val Loss:   1.9,  Val Acc: 67.51%,  Time: 0:05:20
# Iter:   1000,  Train Loss:  0.02,  Train Acc: 99.22%,  Val Loss:   1.9,  Val Acc: 67.51%,  Time: 0:05:23
# Iter:   1010,  Train Loss: 0.023,  Train Acc: 99.22%,  Val Loss:   1.9,  Val Acc: 68.30%,  Time: 0:05:26
# Iter:   1020,  Train Loss: 0.0039,  Train Acc: 100.00%,  Val Loss:   1.9,  Val Acc: 68.75%,  Time: 0:05:29
# Iter:   1030,  Train Loss: 0.021,  Train Acc: 98.44%,  Val Loss:   1.9,  Val Acc: 66.11%,  Time: 0:05:32
# Iter:   1040,  Train Loss: 0.062,  Train Acc: 96.09%,  Val Loss:   1.9,  Val Acc: 66.75%,  Time: 0:05:36
# Iter:   1050,  Train Loss: 0.031,  Train Acc: 99.22%,  Val Loss:   1.9,  Val Acc: 66.30%,  Time: 0:05:39
# Iter:   1060,  Train Loss:  0.08,  Train Acc: 97.66%,  Val Loss:   1.9,  Val Acc: 68.90%,  Time: 0:05:42
# Iter:   1070,  Train Loss: 0.049,  Train Acc: 99.22%,  Val Loss:   1.9,  Val Acc: 67.17%,  Time: 0:05:45
# Iter:   1080,  Train Loss: 0.017,  Train Acc: 98.44%,  Val Loss:   1.9,  Val Acc: 66.98%,  Time: 0:05:48
# Epoch [9/50]
# Iter:   1090,  Train Loss: 0.018,  Train Acc: 99.22%,  Val Loss:   1.9,  Val Acc: 69.54%,  Time: 0:05:51
# Iter:   1100,  Train Loss: 0.002,  Train Acc: 100.00%,  Val Loss:   1.9,  Val Acc: 66.30%,  Time: 0:05:55
# Iter:   1110,  Train Loss: 0.0052,  Train Acc: 100.00%,  Val Loss:   2.0,  Val Acc: 68.68%,  Time: 0:05:58
# Iter:   1120,  Train Loss: 0.0082,  Train Acc: 100.00%,  Val Loss:   2.0,  Val Acc: 66.91%,  Time: 0:06:01
# Iter:   1130,  Train Loss: 0.015,  Train Acc: 99.22%,  Val Loss:   2.0,  Val Acc: 67.55%,  Time: 0:06:04
# No optimization for a long time, auto-stopping...

# %%
import json

with open(config.log_path + '/train_dict.json', 'r', encoding='utf-8') as file:
    train_dict = json.load(file)
with open(config.log_path + '/test_dict.json', 'r', encoding='utf-8') as file:
    test_dict = json.load(file)
import matplotlib.pyplot as plt

epochs = range(1, len(train_dict['train_loss']) + 1)
# 设置2行3列的子图布局，因为只有5个指标，所以最后一列会空出来
fig, axs = plt.subplots(2, 3, figsize=(10, 5), sharex=True)
# Flatten axs to easily iterate over it in case of more than one column
axs = axs.flatten()
for i, (key, values) in enumerate(train_dict.items()):
    axs[i].plot(epochs, values, marker='o', label=key)
    axs[i].set_ylabel(key)
    axs[i].set_title(key)  # 添加标题以替代右侧的图例，避免重叠
    axs[i].grid(True)

# 隐藏空的子图
for ax in axs[len(train_dict):]:
    ax.axis('off')
axs[-1].set_xlabel('Epochs')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # 调整布局，留出顶部空间给title或者避免紧凑
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(test_dict['dev_loss']) + 1)
# 设置2行3列的子图布局，因为只有5个指标，所以最后一列会空出来
fig, axs = plt.subplots(2, 3, figsize=(10, 5), sharex=True)
# Flatten axs to easily iterate over it in case of more than one column
axs = axs.flatten()
for i, (key, values) in enumerate(test_dict.items()):
    axs[i].plot(epochs, values, marker='o', label=key)
    axs[i].set_ylabel(key)
    axs[i].set_title(key)  # 添加标题以替代右侧的图例，避免重叠
    axs[i].grid(True)

# 隐藏空的子图
for ax in axs[len(test_dict):]:
    ax.axis('off')
axs[-1].set_xlabel('Epochs')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # 调整布局，留出顶部空间给title或者避免紧凑
plt.show()
